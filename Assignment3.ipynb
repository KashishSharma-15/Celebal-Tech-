# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings

df= pd.read_csv("D:/celebal tech intership/cancer_data.csv")
df
# Out:
#       Age  Gender        BMI  Smoking  GeneticRisk  PhysicalActivity  \
# 0      58       1  16.085313        0            1          8.146251
# 1      71       0  30.828784        0            1          9.361630
# 2      48       1  38.785084        0            2          5.135179
# 3      34       0  30.040295        0            0          9.502792
# 4      62       1  35.479721        0            0          5.356890
# ...   ...     ...        ...      ...          ...               ...
# 1495   62       1  25.090025        0            0          9.892167
# 1496   31       0  33.447125        0            1          1.668297
# 1497   63       1  32.613861        1            1          0.466848
# 1498   55       0  25.568216        0            0          7.795317
# 1499   67       1  23.663104        0            0          2.525860
#
#       AlcoholIntake  CancerHistory  Diagnosis
# 0          4.148219              1          1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1500 non-null   int64
#  1   Gender            1500 non-null   int64
#  2   BMI               1500 non-null   float64
#  3   Smoking           1500 non-null   int64
#  4   GeneticRisk       1500 non-null   int64
#  5   PhysicalActivity  1500 non-null   float64
#  6   AlcoholIntake     1500 non-null   float64
#  7   CancerHistory     1500 non-null   int64
#  8   Diagnosis         1500 non-null   int64
# dtypes: float64(3), int64(6)
# memory usage: 105.6 KB

# %%
df.describe()
# Out:
#                Age       Gender          BMI      Smoking  GeneticRisk  \
# count  1500.000000  1500.000000  1500.000000  1500.000000  1500.000000
# mean     50.320000     0.490667    27.513321     0.269333     0.508667
# std      17.640968     0.500080     7.230012     0.443761     0.678895
# min      20.000000     0.000000    15.000291     0.000000     0.000000
# 25%      35.000000     0.000000    21.483134     0.000000     0.000000
# 50%      51.000000     0.000000    27.598494     0.000000     0.000000
# 75%      66.000000     1.000000    33.850837     1.000000     1.000000
# max      80.000000     1.000000    39.958688     1.000000     2.000000
#
#        PhysicalActivity  AlcoholIntake  CancerHistory    Diagnosis
# count       1500.000000    1500.000000    1500.000000  1500.000000
# mean           4.897929       2.417987       0.144000     0.371333
# std            2.866162       1.419318       0.351207     0.483322
# ...

# %%
df.isnull().sum()
# Out:
# Age                 0
# Gender              0
# BMI                 0
# Smoking             0
# GeneticRisk         0
# PhysicalActivity    0
# AlcoholIntake       0
# CancerHistory       0
# Diagnosis           0
# dtype: int64

# %%
sns.histplot(data=df, x='Diagnosis')
plt.xlabel('Diagnosed')
plt.title('Cancer Diagnosis', color='red')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Cancer Diagnosis')

# %%
sns.heatmap(df)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Age'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Box plot of BMI by Diagnosis
plt.figure(figsize=(10, 6))
df.boxplot(column='BMI', by='Diagnosis', grid=False)
plt.title('Box Plot of BMI by Diagnosis')
plt.suptitle('')  # Suppress the automatic title
plt.xlabel('Diagnosis')
plt.ylabel('BMI')
plt.show()

# %%
sns.catplot(df, x='BMI', y= 'Age', kind='box', palette ='winter')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Bar plot of Gender
gender_counts = df['Gender'].value_counts()
plt.figure(figsize=(8, 6))
gender_counts.plot(kind='bar', color=['blue', 'pink'])
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['Male', 'Female'])
plt.show()

# %%
# Pie chart of Diagnosis
diagnosis_counts = df['Diagnosis'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(diagnosis_counts, labels=diagnosis_counts.index, autopct='%1.1f%%', colors=['lightgreen', 'skyblue'], startangle=140)
plt.title('Cancer Diagnosis Distribution')
plt.show()

# %%
# Scatter plot of Age vs. BMI
plt.figure(figsize=(10, 6))
plt.scatter(df['Age'], df['BMI'], c=df['Diagnosis'], cmap='coolwarm', edgecolor='k', alpha=0.7)
plt.title('Scatter Plot of Age vs. BMI')
plt.xlabel('Age')
plt.ylabel('BMI')
plt.colorbar(label='Diagnosis')
plt.show()

# %%
# Suppress specific warnings
warnings.filterwarnings('ignore', category=FutureWarning, module='seaborn')
warnings.filterwarnings('ignore', category=FutureWarning, module='pandas')


# Pair plot
sns.pairplot(df, hue='Diagnosis', diag_kind='kde')
plt.suptitle('Pair Plot of Cancer Data', y=1.02)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
